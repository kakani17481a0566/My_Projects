# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_load = pd.read_csv('bank_stocks_historical_data.csv')

# %%
print(data_load.columns)

print(data_load.dtypes)

print(data_load['Ticker'].unique())
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends',
#        'Stock Splits', 'Ticker'],
#       dtype='object')
# Date             object
# Open            float64
# High            float64
# Low             float64
# Close           float64
# Volume            int64
# Dividends       float64
# Stock Splits    float64
# Ticker           object
# dtype: object
# ['HDFCBANK.NS' 'ICICIBANK.NS' 'KOTAKBANK.NS' 'SBIN.NS' 'AXISBANK.NS']

# %%
line_break ="================================================================================================================="
colors = ['lightcoral', 'lightblue', 'lightgreen', 'peachpuff', 'lavender', 'mintcream', 'palegoldenrod', 'thistle', 'lightyellow', 'skyblue', 'lightpink', 'honeydew', 'lavenderblush']

# %%
stockname = 'HDFCBANK.NS'

# %%
data_load['Date'] = pd.to_datetime(data_load['Date']).dt.strftime('%Y-%m-%d')

# %% [markdown]
# # General Exploration

# %% [markdown]
# ###
# 1. How many rows and columns are in the dataset?

# %%
data_load.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends',
#        'Stock Splits', 'Ticker'],
#       dtype='object')

# %% [markdown]
# ### 2. What are the first five entries in the dataset?

# %%
data_load.head(1)
# Out:
#          Date         Open         High         Low        Close   Volume  \
# 0  2019-09-27  1198.293356  1203.333244  1188.06956  1194.405396  7436585
#
#    Dividends  Stock Splits       Ticker
# 0        0.0           0.0  HDFCBANK.NS

# %% [markdown]
# ### 4. How many unique tickers are present?

# %%
data_load['Ticker'].unique()
# Out:
# array(['HDFCBANK.NS', 'ICICIBANK.NS', 'KOTAKBANK.NS', 'SBIN.NS',
#        'AXISBANK.NS'], dtype=object)

# %% [markdown]
# ### 5. How many missing values exist in each column?

# %%
data_load.isna().sum()
# Out:
# Date            0
# Open            0
# High            0
# Low             0
# Close           0
# Volume          0
# Dividends       0
# Stock Splits    0
# Ticker          0
# dtype: int64

# %% [markdown]
# # Time Series Analysis

# %% [markdown]
# ### 6. What is the date range in the dataset?

# %%
min_date = data_load['Date'].min()
max_date =  data_load['Date'].max()

print(f'Start data ==> {max_date}   End Date ==> {max_date}')
# Out:
# Start data ==> 2024-09-27   End Date ==> 2024-09-27

# %% [markdown]
# ### 7. How does the closing price change over time for each ticker?

# %%
df_7 = data_load
print(df_7['Date'].dtypes)
print(line_break)
df_7['Date'] = pd.to_datetime(df_7['Date'] )
print(df_7['Date'].dtypes)
print(line_break)
# Out:
# object
# =================================================================================================================
# datetime64[ns]
# =================================================================================================================

# %%
df_7.set_index('Date', inplace=True)

# %%
df_7 = df_7.groupby('Ticker').resample('YE').max()

# %%
df_7 = df_7[['Close']]
df_7.reset_index(inplace=True)

# %%
df_7

plt.figure(figsize=(15,5))
sns.barplot(data =df_7,hue='Ticker',x= 'Date', y = 'Close', palette=colors, edgecolor= 'black') 
plt.grid()

plt.title('Close Prices by Ticker Over Time')
plt.xlabel('Date')
plt.ylabel('Close Price')

plt.show()
# Out:
# C:\Users\kakan\AppData\Local\Temp\ipykernel_9376\2795497822.py:4: UserWarning: The palette list has more values (13) than needed (5), which may not be intended.
#   sns.barplot(data =df_7,hue='Ticker',x= 'Date', y = 'Close', palette=colors, edgecolor= 'black')

# %% [markdown]
# ### 8. What are the top 5 dates with the highest closing prices?

# %%
df_8 = data_load

for i  in df_8['Ticker'].unique():
    
    temp =  df_8[df_8['Ticker'] == i]
    print(i)
    k =temp[['High','Ticker']].sort_values(by='High', ascending = False).head(5)
    print(k)
    print(line_break)
# Out:
# HDFCBANK.NS
#                    High       Ticker
# Date
# 2024-07-03  1794.000000  HDFCBANK.NS
# 2024-09-26  1788.000000  HDFCBANK.NS
# 2024-09-25  1788.000000  HDFCBANK.NS
# 2024-09-24  1781.650024  HDFCBANK.NS
# 2024-09-27  1778.199951  HDFCBANK.NS
# =================================================================================================================
# ICICIBANK.NS
#                    High        Ticker
# Date
# 2024-09-20  1362.349976  ICICIBANK.NS
# 2024-09-26  1333.349976  ICICIBANK.NS
# 2024-09-27  1333.000000  ICICIBANK.NS
# 2024-09-23  1331.800049  ICICIBANK.NS
# 2024-09-24  1331.400024  ICICIBANK.NS
# =================================================================================================================
# KOTAKBANK.NS
#                    High        Ticker
# Date
# 2021-10-27  2247.328961  KOTAKBANK.NS
# 2021-10-26  2234.361445  KOTAKBANK.NS
# 2021-10-22  2196.107937  KOTAKBANK.NS
# 2021-10-28  2184.487455  KOTAKBANK.NS
# 2021-10-25  2177.455244  KOTAKBANK.NS
# =================================================================================================================
# SBIN.NS
#                   High   Ticker
# Date
# 2024-06-03  912.000000  SBIN.NS
# 2024-07-19  899.000000  SBIN.NS
# 2024-06-04  897.000000  SBIN.NS
# 2024-07-22  895.000000  SBIN.NS
# 2024-07-18  894.900024  SBIN.NS
# =================================================================================================================
# AXISBANK.NS
#                    High       Ticker
# Date
# 2024-07-12  1339.650024  AXISBANK.NS
# 2024-07-15  1324.400024  AXISBANK.NS
# 2024-07-18  1318.599976  AXISBANK.NS
# 2024-07-16  1318.449951  AXISBANK.NS
# 2024-07-19  1309.000000  AXISBANK.NS
# =================================================================================================================

# %% [markdown]
# ### 9. How does the trading volume vary over time?

# %%
df_9 = data_load
df_9['Year'] = 0
df_9.reset_index(inplace=True)
df_9['Year']=df_9['Date'].dt.year
df_9.set_index('Date',inplace=True)
df_9
# Out:
#                    Open         High          Low        Close    Volume  \
# Date
# 2019-09-27  1198.293356  1203.333244  1188.069560  1194.405396   7436585
# 2019-09-30  1179.621748  1190.373462  1167.813965  1178.325684   9109229
# 2019-10-01  1182.213613  1204.773109  1172.229812  1198.821289   9384176
# 2019-10-03  1190.325465  1194.021477  1167.669993  1174.581909   8149438
# 2019-10-04  1187.157616  1189.989506  1137.862736  1142.086548   9201816
# ...                 ...          ...          ...          ...       ...
# 2024-09-23  1251.500000  1252.449951  1240.550049  1246.800049   5462814
# 2024-09-24  1241.099976  1247.099976  1235.349976  1239.550049   9225946
# 2024-09-25  1238.000000  1271.000000  1231.099976  1268.099976   6853324
# 2024-09-26  1267.550049  1281.650024  1262.250000  1277.099976   7270078
# 2024-09-27  1273.000000  1281.550049  1257.250000  1273.150024  13372000
#
#             Dividends  Stock Splits       Ticker  Year
# Date
# 2019-09-27        0.0           0.0  HDFCBANK.NS  2019
# 2019-09-30        0.0           0.0  HDFCBANK.NS  2019
# 2019-10-01        0.0           0.0  HDFCBANK.NS  2019
# 2019-10-03        0.0           0.0  HDFCBANK.NS  2019
# 2019-10-04        0.0           0.0  HDFCBANK.NS  2019
# ...               ...           ...          ...   ...
# 2024-09-23        0.0           0.0  AXISBANK.NS  2024
# 2024-09-24        0.0           0.0  AXISBANK.NS  2024
# 2024-09-25        0.0           0.0  AXISBANK.NS  2024
# 2024-09-26        0.0           0.0  AXISBANK.NS  2024
# 2024-09-27        0.0           0.0  AXISBANK.NS  2024
#
# [6190 rows x 9 columns]

# %%
from datetime import datetime
# Get the current year
current_year = datetime.now().year
# Display the current year
print(current_year)
# Out:
# 2024

# %%
df_9= df_9[df_9['Year'] == current_year]
df_9= df_9[df_9['Ticker'] == stockname]
df_9 = df_9.resample('ME').max()
df_9['Volume_change_month_to_month'] = 0
df_9.reset_index(inplace=True)

# %%
start = df_9.index.min()
end = df_9.index.max()
for i in df_9.index:
    if start < i < end:
        print(i)
        k = df_9.loc[i]['Volume'] - df_9.loc[i-1]['Volume']
        df_9.loc[i,'Volume_change_month_to_month'] = k
        print(line_break)
df_9
# Out:
# 1
# =================================================================================================================
# 2
# =================================================================================================================
# 3
# =================================================================================================================
# 4
# =================================================================================================================
# 5
# =================================================================================================================
# 6
# =================================================================================================================
# 7
# =================================================================================================================
#         Date         Open         High          Low        Close     Volume  \
# 0 2024-01-31  1683.017598  1686.125187  1669.206199  1676.210571   85072618
# 1 2024-02-29  1455.129536  1460.900704  1436.434898  1446.596069   45660405
# 2 2024-03-31  1445.757590  1451.775390  1430.565026  1440.726318   71806902
# 3 2024-04-30  1536.419530  1536.419530  1520.783118  1528.675293   44467533
# 4 2024-05-31  1530.099976  1545.000000  1524.800049  1531.550049   37039794
# 5 2024-06-30  1707.949951  1716.949951  1691.099976  1711.349976   45065598
# 6 2024-07-31  1791.000000  1794.000000  1764.650024  1768.650024   61608901
# 7 2024-08-31  1656.000000  1675.949951  1647.349976  1660.099976  222671050
# 8 2024-09-30  1777.000000  1788.000000  1768.050049  1783.449951   30311693
#
#    Dividends  Stock Splits       Ticker  Year  Volume_change_month_to_month
# 0        0.0           0.0  HDFCBANK.NS  2024                             0
# 1        0.0           0.0  HDFCBANK.NS  2024                     -39412213
# 2        0.0           0.0  HDFCBANK.NS  2024                      26146497
# 3        0.0           0.0  HDFCBANK.NS  2024                     -27339369
# 4       19.5           0.0  HDFCBANK.NS  2024                      -7427739
# 5        0.0           0.0  HDFCBANK.NS  2024                       8025804
# 6        0.0           0.0  HDFCBANK.NS  2024                      16543303
# 7        0.0           0.0  HDFCBANK.NS  2024                     161062149
# 8        0.0           0.0  HDFCBANK.NS  2024                             0

# %%
df_9 = df_9[['Date','Volume_change_month_to_month']]

plt.figure(figsize=(15, 5))
sns.lineplot(data=df_9, x='Date', y='Volume_change_month_to_month', marker = 'o')


plt.title('Monthly Volume Change Over Time', fontsize=16)
plt.xlabel('Date', fontsize=14)
plt.ylabel('Volume Change (Month to Month)', fontsize=14)
plt.xticks(rotation=45)  
plt.grid(True)


plt.tight_layout()
plt.show()

# %% [markdown]
# ### 11. What is the mean closing price for each ticker?
# ### 12. What is the median trading volume for each ticker?
# ### 13. What is the standard deviation of the closing prices for each ticker?
# ### 14. What are the minimum and maximum closing prices for each ticker?
# ### 15. What are the average daily returns for each ticker?

# %%
df_11 = data_load
df_11 = data_load
df_11['Year'] = 0
df_11.reset_index(inplace=True)
df_11['Year']=df_11['Date'].dt.year
df_11.set_index('Date',inplace=True)
df_11
# Out:
#                    Open         High          Low        Close    Volume  \
# Date
# 2019-09-27  1198.293356  1203.333244  1188.069560  1194.405396   7436585
# 2019-09-30  1179.621748  1190.373462  1167.813965  1178.325684   9109229
# 2019-10-01  1182.213613  1204.773109  1172.229812  1198.821289   9384176
# 2019-10-03  1190.325465  1194.021477  1167.669993  1174.581909   8149438
# 2019-10-04  1187.157616  1189.989506  1137.862736  1142.086548   9201816
# ...                 ...          ...          ...          ...       ...
# 2024-09-23  1251.500000  1252.449951  1240.550049  1246.800049   5462814
# 2024-09-24  1241.099976  1247.099976  1235.349976  1239.550049   9225946
# 2024-09-25  1238.000000  1271.000000  1231.099976  1268.099976   6853324
# 2024-09-26  1267.550049  1281.650024  1262.250000  1277.099976   7270078
# 2024-09-27  1273.000000  1281.550049  1257.250000  1273.150024  13372000
#
#             Dividends  Stock Splits       Ticker  Year
# Date
# 2019-09-27        0.0           0.0  HDFCBANK.NS  2019
# 2019-09-30        0.0           0.0  HDFCBANK.NS  2019
# 2019-10-01        0.0           0.0  HDFCBANK.NS  2019
# 2019-10-03        0.0           0.0  HDFCBANK.NS  2019
# 2019-10-04        0.0           0.0  HDFCBANK.NS  2019
# ...               ...           ...          ...   ...
# 2024-09-23        0.0           0.0  AXISBANK.NS  2024
# 2024-09-24        0.0           0.0  AXISBANK.NS  2024
# 2024-09-25        0.0           0.0  AXISBANK.NS  2024
# 2024-09-26        0.0           0.0  AXISBANK.NS  2024
# 2024-09-27        0.0           0.0  AXISBANK.NS  2024
#
# [6190 rows x 9 columns]

# %%
df_11 =df_11[df_11['Year'] == current_year]
df_11
# Out:
#                    Open         High          Low        Close    Volume  \
# Date
# 2024-01-01  1683.017598  1686.125187  1669.206199  1675.223999   7119843
# 2024-01-02  1675.914685  1679.860799  1665.950651  1676.210571  14621046
# 2024-01-03  1679.071480  1681.735059  1646.466666  1650.363525  14194881
# 2024-01-04  1655.394910  1672.116520  1648.193203  1668.071777  13367028
# 2024-01-05  1664.421596  1681.932477  1645.628180  1659.538208  15944735
# ...                 ...          ...          ...          ...       ...
# 2024-09-23  1251.500000  1252.449951  1240.550049  1246.800049   5462814
# 2024-09-24  1241.099976  1247.099976  1235.349976  1239.550049   9225946
# 2024-09-25  1238.000000  1271.000000  1231.099976  1268.099976   6853324
# 2024-09-26  1267.550049  1281.650024  1262.250000  1277.099976   7270078
# 2024-09-27  1273.000000  1281.550049  1257.250000  1273.150024  13372000
#
#             Dividends  Stock Splits       Ticker  Year
# Date
# 2024-01-01        0.0           0.0  HDFCBANK.NS  2024
# 2024-01-02        0.0           0.0  HDFCBANK.NS  2024
# 2024-01-03        0.0           0.0  HDFCBANK.NS  2024
# 2024-01-04        0.0           0.0  HDFCBANK.NS  2024
# 2024-01-05        0.0           0.0  HDFCBANK.NS  2024
# ...               ...           ...          ...   ...
# 2024-09-23        0.0           0.0  AXISBANK.NS  2024
# 2024-09-24        0.0           0.0  AXISBANK.NS  2024
# 2024-09-25        0.0           0.0  AXISBANK.NS  2024
# 2024-09-26        0.0           0.0  AXISBANK.NS  2024
# 2024-09-27        0.0           0.0  AXISBANK.NS  2024
#
# [915 rows x 9 columns]

# %%
df_11 =df_11.groupby('Ticker').resample('ME').max()

# %%
for i in df_11['Ticker'].unique():
    print (i)
    temp = df_11[df_11['Ticker']==i]
    print(temp['Close'].describe())
    print(line_break)
    print(i)
    temp['Close'].describe().plot(kind='bar', color=colors, edgecolor = 'black')
    plt.show()
# Out:
# AXISBANK.NS
# count       9.000000
# mean     1197.216458
# std        78.240561
# min      1100.051025
# 25%      1136.073120
# 50%      1181.250000
# 75%      1277.099976
# max      1317.300049
# Name: Close, dtype: float64
# =================================================================================================================
# AXISBANK.NS
# HDFCBANK.NS
# count       9.000000
# mean     1616.367581
# std       132.371632
# min      1440.726318
# 25%      1528.675293
# 50%      1660.099976
# 75%      1711.349976
# max      1783.449951
# Name: Close, dtype: float64
# =================================================================================================================
# HDFCBANK.NS
# ICICIBANK.NS
# count       9.000000
# mean     1162.795770
# std       101.280022
# min      1020.266785
# 25%      1087.735840
# 50%      1150.247803
# 75%      1229.199951
# max      1338.449951
# Name: Close, dtype: float64
# =================================================================================================================
# ICICIBANK.NS
# KOTAKBANK.NS
# count       9.000000
# mean     1833.042792
# std        65.484767
# min      1709.126709
# 25%      1820.954102
# 50%      1828.545898
# 75%      1851.171021
# max      1934.699951
# Name: Close, dtype: float64
# =================================================================================================================
# KOTAKBANK.NS
# SBIN.NS
# count      9.000000
# mean     811.098246
# std       82.848854
# min      632.837524
# 25%      775.052612
# 50%      824.799988
# 75%      862.650024
# max      905.650024
# Name: Close, dtype: float64
# =================================================================================================================
# SBIN.NS

# %% [markdown]
# # Visualizations

# %% [markdown]
# ### 16. Can you plot the closing price over time for each ticker?

# %%
df_11 =data_load
df_11['Ticker'].unique()
df_11=  df_11[df_11['Year'] == current_year]



for i in df_11['Ticker'].unique():
    print(i)
    df_11[df_11['Ticker'] == i].resample('ME').max('Close').plot(kind='line',y='Close', marker= 'o' ,figsize=(15,5))
    plt.grid()
    
    plt.xlabel('YEAR')
    plt.ylabel('closing')   
    plt.title(' closing price over time for each ticker')
    plt.show()
    print(line_break)
# Out:
# HDFCBANK.NS
# =================================================================================================================
# ICICIBANK.NS
# =================================================================================================================
# KOTAKBANK.NS
# =================================================================================================================
# SBIN.NS
# =================================================================================================================
# AXISBANK.NS
# =================================================================================================================

# %% [markdown]
# ### 17. How does the trading volume distribute across different tickers?

# %%
df_17 = data_load
df_17[df_17['Year'] == current_year]


df_11 =data_load
df_17['Ticker'].unique()
df_17=  df_17[df_17['Year'] == current_year]



for i in df_11['Ticker'].unique():
    print(i)
    df_17[df_17['Ticker'] == i].resample('ME').max('Volume').plot(kind='line',y='Volume', marker= 'o' ,figsize=(15,5))
    plt.grid()
    
    plt.xlabel('YEAR')
    plt.ylabel('Volume')   
    plt.title(' volume distribute across different tickers')
    plt.show()
    print(line_break)
# Out:
# HDFCBANK.NS
# =================================================================================================================
# ICICIBANK.NS
# =================================================================================================================
# KOTAKBANK.NS
# =================================================================================================================
# SBIN.NS
# =================================================================================================================
# AXISBANK.NS
# =================================================================================================================
