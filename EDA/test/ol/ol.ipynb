# %%
import pandas as pd
import matplotlib as mt

# %% [markdown]
# Olympics

# %%
main_data = pd.read_csv("athletes new.csv")

# %%
main_data.isna().sum()
# Out:
# code                 0
# name                 0
# name_short           0
# name_tv              0
# gender               0
# function             0
# country_code         0
# country              0
# country_full         0
# nationality          0
# nationality_full     0
# nationality_code     0
# height               0
# weight              16
# disciplines          0
# events               0
# birth_date           0
# dtype: int64

# %%
main_data[main_data['weight'].isna()]
# Out:
#           code                name     name_short             name_tv  gender  \
# 457    1566088          TUGSUZ Eda       TUGSUZ E          Eda TUGSUZ  Female
# 537    1571545    LEVCHENKO Yuliia    LEVCHENKO Y    Yuliia LEVCHENKO  Female
# 684    1892137  OGRODNIKOVA Nikola  OGRODNIKOVA N  Nikola OGRODNIKOVA  Female
# 1271   1922750   JASIUNAITE Liveta   JASIUNAITE L   Liveta JASIUNAITE  Female
# 2352   1939961    MANSFIELD Lauren    MANSFIELD L    Lauren MANSFIELD  Female
# 2607   1958471      BRIZUELA Dario     BRIZUELA D      Dario BRIZUELA    Male
# 2939   1912007      ORIE Delicious         ORIE D      Delicious ORIE    Male
# 3817   1966661      MATTERN Carson      MATTERN C      Carson MATTERN    Male
# 4643   1960015          LETE Elene         LETE E          Elene LETE  Female
# 4644   1960019         LOPEZ Vicky        LOPEZ V         Vicky LOPEZ  Female
# 5863   1538253     ALONSO Agostina       ALONSO A     Agostina ALONSO  Female
# ...

# %%
avg_weight = (main_data['weight'].max() + main_data['weight'].min())/2
avg_weight = int(avg_weight)
avg_weight
# Out:
# 56

# %%
main_data[main_data['weight'].isna()] = avg_weight

# %%
main_data.isna().sum()
# Out:
# code                0
# name                0
# name_short          0
# name_tv             0
# gender              0
# function            0
# country_code        0
# country             0
# country_full        0
# nationality         0
# nationality_full    0
# nationality_code    0
# height              0
# weight              0
# disciplines         0
# events              0
# birth_date          0
# dtype: int64

# %%
main_data.columns
# Out:
# Index(['code', 'name', 'name_short', 'name_tv', 'gender', 'function',
#        'country_code', 'country', 'country_full', 'nationality',
#        'nationality_full', 'nationality_code', 'height', 'weight',
#        'disciplines', 'events', 'birth_date'],
#       dtype='object')

# %% [markdown]
# Basic Data Overview

# %%
#1. What is the total number of records in the dataset?

main_data.size
# Out:
# 188955
