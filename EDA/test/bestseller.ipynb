# %%
import pandas as pd

# %%
df = pd.read_csv('//192.168.0.1/g/INE/vis_pands/lesson files/data/bestsellers.csv')

# %%
df = df.sort_values(by='Year')
df
# Out:
#                                                   Name             Author  \
# 25   Arguing with Idiots: How to Stop Small Minds a...         Glenn Beck
# 513               Twilight (The Twilight Saga, Book 1)    Stephenie Meyer
# 512                             True Compass: A Memoir  Edward M. Kennedy
# 520                            Under the Dome: A Novel       Stephen King
# 524                                           Watchmen         Alan Moore
# ..                                                 ...                ...
# 252                          Oh, the Places You'll Go!          Dr. Seuss
# 33                                            Becoming     Michelle Obama
# 529  What Should Danny Do? (The Power to Choose Ser...          Adir Levy
# 549  You Are a Badass: How to Stop Doubting Your Gr...        Jen Sincero
# 534                            Where the Crawdads Sing        Delia Owens
#
#      User Rating  Reviews  Price  Year        Genre
# ...

# %%
year_books_published =  df['Year'].value_counts()
year_books_published
# Out:
# Year
# 2009    50
# 2010    50
# 2011    50
# 2012    50
# 2013    50
# 2014    50
# 2015    50
# 2016    50
# 2017    50
# 2018    50
# 2019    50
# Name: count, dtype: int64

# %%
type(year_books_published)
# Out:
# pandas.core.series.Series

# %%
df.plot(kind='bar'
        ,x='Year'
        ,xlabel='Year'
        ,y='Reviews'
        ,ylabel= 'Reviews'
        ,figsize=(10,10))
# Out:
# <Axes: xlabel='Year', ylabel='Reviews'>

# %%
df.plot(
    kind='box'
    ,x='Year'
        ,xlabel='Year'
        ,y='Reviews'
        ,ylabel= 'Reviews'
)
# Out:
# <Axes: xlabel='Year', ylabel='Reviews'>

# %%
df['Year'].plot(
    kind='area'
)
# Out:
# <Axes: >

# %%
df['Year'].plot(
    kind= 'hist',
    color='red'
   , figsize=(10,10)
   
)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df
# Out:
#                                                   Name             Author  \
# 25   Arguing with Idiots: How to Stop Small Minds a...         Glenn Beck
# 513               Twilight (The Twilight Saga, Book 1)    Stephenie Meyer
# 512                             True Compass: A Memoir  Edward M. Kennedy
# 520                            Under the Dome: A Novel       Stephen King
# 524                                           Watchmen         Alan Moore
# ..                                                 ...                ...
# 252                          Oh, the Places You'll Go!          Dr. Seuss
# 33                                            Becoming     Michelle Obama
# 529  What Should Danny Do? (The Power to Choose Ser...          Adir Levy
# 549  You Are a Badass: How to Stop Doubting Your Gr...        Jen Sincero
# 534                            Where the Crawdads Sing        Delia Owens
#
#      User Rating  Reviews  Price  Year        Genre
# ...

# %%
piv_user_rating = pd.DataFrame(df['User Rating'].value_counts())
type(piv_user_rating)
# Out:
# pandas.core.frame.DataFrame

# %%
piv_user_rating.plot(kind= 'bar'                     
                     )
# Out:
# <Axes: xlabel='User Rating'>

# %%
df['Genre'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
piv_author =pd.DataFrame(df['Author'].value_counts() )
type(piv_author)

piv_author
# Out:
#                                     count
# Author
# Jeff Kinney                            12
# Rick Riordan                           11
# Suzanne Collins                        11
# Gary Chapman                           11
# American Psychological Association     10
# ...                                   ...
# Alex Michaelides                        1
# M Prefontaine                           1
# Amy Shields                             1
# Adir Levy                               1
# Delia Owens                             1
#
# [248 rows x 1 columns]

# %%
piv_author[piv_author['count'] > 6].plot(kind='bar')
# Out:
# <Axes: xlabel='Author'>

# %%
piv_author.plot(kind='line',figsize=(10,5))
# Out:
# <Axes: xlabel='Author'>
