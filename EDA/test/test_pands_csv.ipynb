# %%
pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ----------------------------------- ---- 10.2/11.5 MB 57.9 MB/s eta 0:00:01
#    ---------------------------------------- 11.5/11.5 MB 44.9 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
#reading a CSV file

test = pd.read_csv('test.csv')

# %%
type(test)
# Out:
# pandas.core.frame.DataFrame

# %%
test.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
test.index
# Out:
# RangeIndex(start=0, stop=18, step=1)

# %%
test.set_index('InvoiceNo', inplace= True)

# %%
test.index
# Out:
# Index([578678, 558876, 557057, 558485, 548163, 559706, 579550, 562593, 558028,
#        543022, 555560, 577297, 563017, 578292, 547397, 540247, 537773, 542794],
#       dtype='int64', name='InvoiceNo')

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18 entries, 578678 to 542794
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   StockCode    18 non-null     object
#  1   Description  18 non-null     object
#  2   Quantity     18 non-null     int64
#  3   InvoiceDate  18 non-null     object
#  4   UnitPrice    18 non-null     float64
#  5   CustomerID   14 non-null     float64
#  6   Country      18 non-null     object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 1.1+ KB

# %%
test.describe()
# Out:
#         Quantity  UnitPrice    CustomerID
# count  18.000000  18.000000     14.000000
# mean    8.888889   3.375556  15714.500000
# std    16.869356   5.688045   1746.391257
# min     1.000000   0.380000  12630.000000
# 25%     1.000000   0.850000  14726.750000
# 50%     3.500000   1.250000  16282.500000
# 75%     9.000000   3.910000  16825.000000
# max    72.000000  24.960000  17841.000000

# %%
test.dtypes
# Out:
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# UnitPrice      float64
# CustomerID     float64
# Country         object
# dtype: object

# %%
test[['Description','Country']]
# Out:
#                                    Description         Country
# InvoiceNo
# 578678           HEART SHAPE WIRELESS DOORBELL  United Kingdom
# 558876                 NO JUNK MAIL METAL SIGN  United Kingdom
# 557057                 PARISIENNE KEY CABINET   United Kingdom
# 558485                STRAWBERRY CHARLOTTE BAG  United Kingdom
# 548163               WHEELBARROW FOR CHILDREN   United Kingdom
# 559706           SCENTED VELVET LOUNGE CANDLE   United Kingdom
# 579550               RED RETROSPOT OVEN GLOVE          Finland
# 562593     CHRISTMAS STAR WISH LIST CHALKBOARD  United Kingdom
# 558028         AIRLINE BAG VINTAGE JET SET RED  United Kingdom
# 543022          PINK GAUZE BUTTERFLY LAMPSHADE  United Kingdom
# 555560             RED RETROSPOT CHARLOTTE BAG  United Kingdom
# 577297        TRADITIONAL PICK UP STICKS GAME   United Kingdom
# 563017             CHARLOTTE BAG APPLES DESIGN  United Kingdom
# 578292                  WRAP CHRISTMAS VILLAGE  United Kingdom
# ...

# %%
print(test.index)  # Check the index labels
# Out:
# Index([578678, 558876, 557057, 558485, 548163, 559706, 579550, 562593, 558028,
#        543022, 555560, 577297, 563017, 578292, 547397, 540247, 537773, 542794],
#       dtype='int64', name='InvoiceNo')

# %%
test.loc[578678:548163]
# Out:
#           StockCode                    Description  Quantity  \
# InvoiceNo
# 578678        79160  HEART SHAPE WIRELESS DOORBELL         1
# 558876        21179        NO JUNK MAIL METAL SIGN         3
# 557057        23110        PARISIENNE KEY CABINET          4
# 558485        20723       STRAWBERRY CHARLOTTE BAG         1
# 548163        22526      WHEELBARROW FOR CHILDREN          1
#
#                 InvoiceDate  UnitPrice  CustomerID         Country
# InvoiceNo
# 578678     11/24/2011 19:59       2.10     17841.0  United Kingdom
# 558876       7/4/2011 13:36       0.39     17841.0  United Kingdom
# 557057      6/16/2011 14:46       5.75     16843.0  United Kingdom
# 558485      6/30/2011 10:11       0.85         NaN  United Kingdom
# 548163      3/29/2011 13:43      24.96         NaN  United Kingdom

# %%
test.iloc[1:10]
# Out:
#           StockCode                          Description  Quantity  \
# InvoiceNo
# 558876        21179              NO JUNK MAIL METAL SIGN         3
# 557057        23110              PARISIENNE KEY CABINET          4
# 558485        20723             STRAWBERRY CHARLOTTE BAG         1
# 548163        22526            WHEELBARROW FOR CHILDREN          1
# 559706        21287        SCENTED VELVET LOUNGE CANDLE         72
# 579550        21154            RED RETROSPOT OVEN GLOVE         10
# 562593        22596  CHRISTMAS STAR WISH LIST CHALKBOARD        12
# 558028        22374      AIRLINE BAG VINTAGE JET SET RED         4
# 543022       44089A       PINK GAUZE BUTTERFLY LAMPSHADE         4
#
#                 InvoiceDate  UnitPrice  CustomerID         Country
# InvoiceNo
# 558876       7/4/2011 13:36       0.39     17841.0  United Kingdom
# 557057      6/16/2011 14:46       5.75     16843.0  United Kingdom
# 558485      6/30/2011 10:11       0.85         NaN  United Kingdom
# ...

# %%
test['Quantity'].mean()
# Out:
# np.float64(8.88888888888889)

# %%
test['Quantity'] >= 8
# Out:
# InvoiceNo
# 578678    False
# 558876    False
# 557057    False
# 558485    False
# 548163    False
# 559706     True
# 579550     True
# 562593     True
# 558028    False
# 543022    False
# 555560    False
# 577297    False
# 563017     True
# 578292     True
# 547397    False
# 540247    False
# 537773    False
# 542794    False
# Name: Quantity, dtype: bool

# %%
test[test['Quantity']>=8]
# Out:
#           StockCode                          Description  Quantity  \
# InvoiceNo
# 559706        21287        SCENTED VELVET LOUNGE CANDLE         72
# 579550        21154            RED RETROSPOT OVEN GLOVE         10
# 562593        22596  CHRISTMAS STAR WISH LIST CHALKBOARD        12
# 563017        23204          CHARLOTTE BAG APPLES DESIGN        10
# 578292        22959               WRAP CHRISTMAS VILLAGE        25
#
#                 InvoiceDate  UnitPrice  CustomerID         Country
# InvoiceNo
# 559706      7/12/2011 10:02       0.38     16609.0  United Kingdom
# 579550     11/30/2011 10:48       1.25     12630.0         Finland
# 562593       8/7/2011 15:43       1.25     16549.0  United Kingdom
# 563017      8/11/2011 12:48       0.85     13198.0  United Kingdom
# 578292     11/23/2011 14:35       0.42     13174.0  United Kingdom

# %%
test
# Out:
#           StockCode                          Description  Quantity  \
# InvoiceNo
# 578678        79160        HEART SHAPE WIRELESS DOORBELL         1
# 558876        21179              NO JUNK MAIL METAL SIGN         3
# 557057        23110              PARISIENNE KEY CABINET          4
# 558485        20723             STRAWBERRY CHARLOTTE BAG         1
# 548163        22526            WHEELBARROW FOR CHILDREN          1
# 559706        21287        SCENTED VELVET LOUNGE CANDLE         72
# 579550        21154            RED RETROSPOT OVEN GLOVE         10
# 562593        22596  CHRISTMAS STAR WISH LIST CHALKBOARD        12
# 558028        22374      AIRLINE BAG VINTAGE JET SET RED         4
# 543022       44089A       PINK GAUZE BUTTERFLY LAMPSHADE         4
# 555560        20724          RED RETROSPOT CHARLOTTE BAG         6
# 577297        23570     TRADITIONAL PICK UP STICKS GAME          2
# 563017        23204          CHARLOTTE BAG APPLES DESIGN        10
# ...

# %%
#adding new columns

test['total_price']=test['Quantity'] * test['UnitPrice']

# %%
test
# Out:
#           StockCode                          Description  Quantity  \
# InvoiceNo
# 578678        79160        HEART SHAPE WIRELESS DOORBELL         1
# 558876        21179              NO JUNK MAIL METAL SIGN         3
# 557057        23110              PARISIENNE KEY CABINET          4
# 558485        20723             STRAWBERRY CHARLOTTE BAG         1
# 548163        22526            WHEELBARROW FOR CHILDREN          1
# 559706        21287        SCENTED VELVET LOUNGE CANDLE         72
# 579550        21154            RED RETROSPOT OVEN GLOVE         10
# 562593        22596  CHRISTMAS STAR WISH LIST CHALKBOARD        12
# 558028        22374      AIRLINE BAG VINTAGE JET SET RED         4
# 543022       44089A       PINK GAUZE BUTTERFLY LAMPSHADE         4
# 555560        20724          RED RETROSPOT CHARLOTTE BAG         6
# 577297        23570     TRADITIONAL PICK UP STICKS GAME          2
# 563017        23204          CHARLOTTE BAG APPLES DESIGN        10
# ...

# %%
test[test['CustomerID'].isna()]
# Out:
#           StockCode                     Description  Quantity  \
# InvoiceNo
# 558485        20723        STRAWBERRY CHARLOTTE BAG         1
# 548163        22526       WHEELBARROW FOR CHILDREN          1
# 547397        20711                 JUMBO BAG TOYS          1
# 542794        21231  SWEETHEART CERAMIC TRINKET BOX         1
#
#                InvoiceDate  UnitPrice  CustomerID         Country  total_price
# InvoiceNo
# 558485     6/30/2011 10:11       0.85         NaN  United Kingdom         0.85
# 548163     3/29/2011 13:43      24.96         NaN  United Kingdom        24.96
# 547397     3/22/2011 16:55       4.13         NaN  United Kingdom         4.13
# 542794      2/1/2011 10:56       2.46         NaN  United Kingdom         2.46

# %%
test
# Out:
#           StockCode                          Description  Quantity  \
# InvoiceNo
# 578678        79160        HEART SHAPE WIRELESS DOORBELL         1
# 558876        21179              NO JUNK MAIL METAL SIGN         3
# 557057        23110              PARISIENNE KEY CABINET          4
# 558485        20723             STRAWBERRY CHARLOTTE BAG         1
# 548163        22526            WHEELBARROW FOR CHILDREN          1
# 559706        21287        SCENTED VELVET LOUNGE CANDLE         72
# 579550        21154            RED RETROSPOT OVEN GLOVE         10
# 562593        22596  CHRISTMAS STAR WISH LIST CHALKBOARD        12
# 558028        22374      AIRLINE BAG VINTAGE JET SET RED         4
# 543022       44089A       PINK GAUZE BUTTERFLY LAMPSHADE         4
# 555560        20724          RED RETROSPOT CHARLOTTE BAG         6
# 577297        23570     TRADITIONAL PICK UP STICKS GAME          2
# 563017        23204          CHARLOTTE BAG APPLES DESIGN        10
# ...

# %%
pip install matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
#    -------------- ------------------------- 2.9/7.8 MB 15.2 MB/s eta 0:00:01
#    ---------------------------------------- 7.8/7.8 MB 21.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 2.2/2.2 MB 41.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ---------------------------------------- 2.6/2.6 MB 37.0 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
test['Quantity'].plot(kind='line')
# Out:
# Matplotlib is building the font cache; this may take a moment.
# <Axes: xlabel='InvoiceNo'>
