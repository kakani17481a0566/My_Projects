# %%
import pandas as pd

# %%
books = pd.read_csv('bestsellers.csv')

# %%
books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         28 non-null     object
#  1   Author       28 non-null     object
#  2   User Rating  26 non-null     float64
#  3   Reviews      28 non-null     int64
#  4   Price        28 non-null     int64
#  5   Year         28 non-null     int64
#  6   Genre        28 non-null     object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 1.7+ KB

# %%
books
# Out:
#                                                  Name  \
# 0                       10-Day Green Smoothie Cleanse
# 1                                   11/22/63: A Novel
# 2             12 Rules for Life: An Antidote to Chaos
# 3                              1984 (Signet Classics)
# 4   5,000 Awesome Facts (About Everything!) (Natio...
# 5       A Dance with Dragons (A Song of Ice and Fire)
# 6   A Game of Thrones / A Clash of Kings / A Storm...
# 7                      A Gentleman in Moscow: A Novel
# 8       A Higher Loyalty: Truth, Lies, and Leadership
# 9                           A Man Called Ove: A Novel
# 10                          A Man Called Ove: A Novel
# 11  A Patriot's History of the United States: From...
# 12                            A Stolen Life: A Memoir
# 13                   A Wrinkle in Time (Time Quintet)
# 14  Act Like a Lady, Think Like a Man: What Men Re...
# 15  Adult Coloring Book Designs: Stress Relief Col...
# ...

# %%
books['User Rating'].max()
# Out:
# np.float64(4.8)

# %%
User_Rating = books['User Rating']

# %%
books.plot(kind='scatter' ,x='Reviews',y ='Price' )
# Out:
# <Axes: xlabel='Reviews', ylabel='Price'>

# %%
User_Rating = books['User Rating'].value_counts()
User_Rating

User_Rating.plot(kind='bar'
                 ,x='User'
                 ,y='Rating'
                 ,ylabel='Value'
                 ,xlabel='rating'
                 ,title='Rating BAR Graph'
                 ,figsize=(10,5))
# Out:
# <Axes: title={'center': 'Rating BAR Graph'}, xlabel='rating', ylabel='Value'>

# %%
User_Rating
# Out:
# User Rating
# 4.6    11
# 4.7     7
# 4.5     3
# 4.8     2
# 4.4     2
# 4.2     1
# Name: count, dtype: int64

# %%
books['User Rating'].plot(
    kind='line',
    linewidth= 4
    )
# Out:
# <Axes: >

# %%
books
# Out:
#                                                  Name  \
# 0                       10-Day Green Smoothie Cleanse
# 1                                   11/22/63: A Novel
# 2             12 Rules for Life: An Antidote to Chaos
# 3                              1984 (Signet Classics)
# 4   5,000 Awesome Facts (About Everything!) (Natio...
# 5       A Dance with Dragons (A Song of Ice and Fire)
# 6   A Game of Thrones / A Clash of Kings / A Storm...
# 7                      A Gentleman in Moscow: A Novel
# 8       A Higher Loyalty: Truth, Lies, and Leadership
# 9                           A Man Called Ove: A Novel
# 10                          A Man Called Ove: A Novel
# 11  A Patriot's History of the United States: From...
# 12                            A Stolen Life: A Memoir
# 13                   A Wrinkle in Time (Time Quintet)
# 14  Act Like a Lady, Think Like a Man: What Men Re...
# 15  Adult Coloring Book Designs: Stress Relief Col...
# ...

# %%
books.plot(kind='bar',
           y='Price',
           x='Year')
# Out:
# <Axes: xlabel='Year'>

# %%
import pandas as pd

# Assuming books is your DataFrame
df = books.sort_values(by='Year')

# Display the sorted DataFrame
print(df)
# Out:
#                                                  Name  \
# 14  Act Like a Lady, Think Like a Man: What Men Re...
# 25  Arguing with Idiots: How to Stop Small Minds a...
# 27                Autobiography of Mark Twain, Vol. 1
# 11  A Patriot's History of the United States: From...
# 12                            A Stolen Life: A Memoir
# 5       A Dance with Dragons (A Song of Ice and Fire)
# 1                                   11/22/63: A Novel
# 22                                          Allegiant
# 24                           And the Mountains Echoed
# 6   A Game of Thrones / A Clash of Kings / A Storm...
# 20                        All the Light We Cannot See
# 21                        All the Light We Cannot See
# 17     Adult Coloring Book: Stress Relieving Patterns
# 16  Adult Coloring Book: Stress Relieving Animal D...
# 23  American Sniper: The Autobiography of the Most...
# 18  Adult Coloring Books: A Coloring Book for Adul...
# ...

# %%
print(df)
# Out:
#                                                  Name  \
# 14  Act Like a Lady, Think Like a Man: What Men Re...
# 25  Arguing with Idiots: How to Stop Small Minds a...
# 27                Autobiography of Mark Twain, Vol. 1
# 11  A Patriot's History of the United States: From...
# 12                            A Stolen Life: A Memoir
# 5       A Dance with Dragons (A Song of Ice and Fire)
# 1                                   11/22/63: A Novel
# 22                                          Allegiant
# 24                           And the Mountains Echoed
# 6   A Game of Thrones / A Clash of Kings / A Storm...
# 20                        All the Light We Cannot See
# 21                        All the Light We Cannot See
# 17     Adult Coloring Book: Stress Relieving Patterns
# 16  Adult Coloring Book: Stress Relieving Animal D...
# 23  American Sniper: The Autobiography of the Most...
# 18  Adult Coloring Books: A Coloring Book for Adul...
# ...
