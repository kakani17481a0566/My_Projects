# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_load = pd.read_csv('mobile.csv')

# %% [markdown]
# # columns

# %%
data_load.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %% [markdown]
# # shape

# %%
data_load.shape
# Out:
# (2000, 21)

# %% [markdown]
# # dtypes

# %%
data_load.dtypes
# Out:
# battery_power      int64
# blue               int64
# clock_speed      float64
# dual_sim           int64
# fc                 int64
# four_g             int64
# int_memory         int64
# m_dep            float64
# mobile_wt          int64
# n_cores            int64
# pc                 int64
# px_height          int64
# px_width           int64
# ram                int64
# sc_h               int64
# sc_w               int64
# talk_time          int64
# three_g            int64
# touch_screen       int64
# wifi               int64
# price_range        int64
# dtype: object

# %% [markdown]
# # checking null values

# %%
data_load.isna().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
data_load.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
#touch_screen     

data_load['touch_screen'].value_counts().plot(kind='bar')

plt.title('Count of Touch Screen Devices')
plt.xlabel('Touch Screen (0 = No, 1 = Yes)')
plt.ylabel('Count')
plt.xticks(rotation=0) 
plt.grid()
plt.show()

# %%
data_load['four_g'].value_counts().plot(kind='bar')


plt.title('Count of 4G Support Devices')
plt.xlabel('4G Support (0 = No, 1 = Yes)')
plt.ylabel('Count')
plt.xticks(rotation=0) 
plt.show()

# %%
plt.figure(figsize=(10, 6))
data_load.boxplot(column='price_range', by='four_g', grid=False)

# Adding titles and labels
plt.title('Price Range Distribution by 4G Support')
plt.suptitle('')  # Suppress the default title to keep it clean
plt.xlabel('4G Support (0 = No, 1 = Yes)')
plt.ylabel('Price Range')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming data_load is your DataFrame
plt.figure(figsize=(10, 6))

plt.scatter(data_load['px_height'], data_load['px_width'], alpha=0.7)

plt.title('Scatter Plot of Pixel Height vs. Pixel Width')
plt.xlabel('Pixel Height')
plt.ylabel('Pixel Width')
plt.grid(True)
plt.show()

# %%
#avg batter power
data_load.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')
