# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Scaling
# - Used to bring features having different magnitudes to similar scale

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
data = [[12000,6],[30000,7],[15000,4],[22000,5]]

# %%
scale = MinMaxScaler()    # Scales values between 0 and 1 (minimum as 0 and maximum as 1)
model = scale.fit(data)
scaled_values = model.transform(data)
scaled_values
# Out:
# array([[0.        , 0.66666667],
#        [1.        , 1.        ],
#        [0.16666667, 0.        ],
#        [0.55555556, 0.33333333]])

# %%
obj = StandardScaler()   #Scales values in terms of mean and standard deviation
model = obj.fit(data)
scales_data = model.transform(data)
scales_data
# Out:
# array([[-1.11643773,  0.4472136 ],
#        [ 1.47657893,  1.34164079],
#        [-0.68426829, -1.34164079],
#        [ 0.32412708, -0.4472136 ]])

# %% [markdown]
# ## Encoding
# - Convert non numeric values to numeric representation
# - One hot encoding
# - Label encoding

# %%
hrt = pd.read_csv('heart.csv')
hrt.head()
# Out:
#     Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0  40.0   M           ATA        140          289          0     Normal
# 1  49.0   F           NAP        160          180          0     Normal
# 2  37.0   M           ATA        130          283          0         ST
# 3  48.0   F           ASY        138          214          0     Normal
# 4  54.0   M           NAP        150          195          0     Normal
#
#    MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0    172              N      0.0       Up             0
# 1    156              N      1.0     Flat             1
# 2     98              N      0.0       Up             0
# 3    108              Y      1.5     Flat             1
# 4    122              N      0.0       Up             0

# %%
from sklearn.preprocessing import OneHotEncoder, LabelEncoder

# %%
hrt.isna().sum()
# Out:
# Age               4
# Sex               3
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
hrt['Age'].fillna(np.mean(hrt['Age']), inplace = True)
# Out:
# C:\Users\kakan\AppData\Local\Temp\ipykernel_20364\2448803564.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   hrt['Age'].fillna(np.mean(hrt['Age']), inplace = True)

# %%
hrt.Sex.value_counts()
# Out:
# Sex
# M    723
# F    192
# Name: count, dtype: int64

# %%
hrt['Sex'].fillna("M", inplace = True)
hrt.isna().sum()
# Out:
# C:\Users\kakan\AppData\Local\Temp\ipykernel_20364\4034235688.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   hrt['Sex'].fillna("M", inplace = True)
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
#Using get_dummies function to encode Sex variable
hrt = pd.get_dummies(hrt, columns=['Sex'], dtype=int)
hrt
# Out:
#       Age ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0    40.0           ATA        140          289          0     Normal    172
# 1    49.0           NAP        160          180          0     Normal    156
# 2    37.0           ATA        130          283          0         ST     98
# 3    48.0           ASY        138          214          0     Normal    108
# 4    54.0           NAP        150          195          0     Normal    122
# ..    ...           ...        ...          ...        ...        ...    ...
# 913  45.0            TA        110          264          0     Normal    132
# 914  68.0           ASY        144          193          1     Normal    141
# 915  57.0           ASY        130          131          0     Normal    115
# 916  57.0           ATA        130          236          0        LVH    174
# 917  38.0           NAP        138          175          0     Normal    173
#
#     ExerciseAngina  Oldpeak ST_Slope  HeartDisease  Sex_F  Sex_M
# 0                N      0.0       Up             0      0      1
# 1                N      1.0     Flat             1      1      0
# 2                N      0.0       Up             0      0      1
# 3                Y      1.5     Flat             1      1      0
# 4                N      0.0       Up             0      0      1
# ..             ...      ...      ...           ...    ...    ...
# 913              N      1.2     Flat             1      0      1
# 914              N      3.4     Flat             1      0      1
# 915              Y      1.2     Flat             1      0      1
# 916              N      0.0     Flat             1      1      0
# 917              N      0.0       Up             0      0      1
#
# [918 rows x 13 columns]

# %%
hrt.drop('Sex_M', inplace=True, axis=1)
hrt
# Out:
#       Age ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0    40.0           ATA        140          289          0     Normal    172
# 1    49.0           NAP        160          180          0     Normal    156
# 2    37.0           ATA        130          283          0         ST     98
# 3    48.0           ASY        138          214          0     Normal    108
# 4    54.0           NAP        150          195          0     Normal    122
# ..    ...           ...        ...          ...        ...        ...    ...
# 913  45.0            TA        110          264          0     Normal    132
# 914  68.0           ASY        144          193          1     Normal    141
# 915  57.0           ASY        130          131          0     Normal    115
# 916  57.0           ATA        130          236          0        LVH    174
# 917  38.0           NAP        138          175          0     Normal    173
#
#     ExerciseAngina  Oldpeak ST_Slope  HeartDisease  Sex_F
# 0                N      0.0       Up             0      0
# 1                N      1.0     Flat             1      1
# 2                N      0.0       Up             0      0
# 3                Y      1.5     Flat             1      1
# 4                N      0.0       Up             0      0
# ..             ...      ...      ...           ...    ...
# 913              N      1.2     Flat             1      0
# 914              N      3.4     Flat             1      0
# 915              Y      1.2     Flat             1      0
# 916              N      0.0     Flat             1      1
# 917              N      0.0       Up             0      0
#
# [918 rows x 12 columns]

# %%
hrt = hrt.rename(columns={'Sex_F' : 'Gender'})
hrt
# Out:
#       Age ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0    40.0           ATA        140          289          0     Normal    172
# 1    49.0           NAP        160          180          0     Normal    156
# 2    37.0           ATA        130          283          0         ST     98
# 3    48.0           ASY        138          214          0     Normal    108
# 4    54.0           NAP        150          195          0     Normal    122
# ..    ...           ...        ...          ...        ...        ...    ...
# 913  45.0            TA        110          264          0     Normal    132
# 914  68.0           ASY        144          193          1     Normal    141
# 915  57.0           ASY        130          131          0     Normal    115
# 916  57.0           ATA        130          236          0        LVH    174
# 917  38.0           NAP        138          175          0     Normal    173
#
#     ExerciseAngina  Oldpeak ST_Slope  HeartDisease  Gender
# 0                N      0.0       Up             0       0
# 1                N      1.0     Flat             1       1
# 2                N      0.0       Up             0       0
# 3                Y      1.5     Flat             1       1
# 4                N      0.0       Up             0       0
# ..             ...      ...      ...           ...     ...
# 913              N      1.2     Flat             1       0
# 914              N      3.4     Flat             1       0
# 915              Y      1.2     Flat             1       0
# 916              N      0.0     Flat             1       1
# 917              N      0.0       Up             0       0
#
# [918 rows x 12 columns]

# %%
hrt = pd.get_dummies(hrt, columns=['ST_Slope'], dtype=int)
hrt
# Out:
#       Age ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0    40.0           ATA        140          289          0     Normal    172
# 1    49.0           NAP        160          180          0     Normal    156
# 2    37.0           ATA        130          283          0         ST     98
# 3    48.0           ASY        138          214          0     Normal    108
# 4    54.0           NAP        150          195          0     Normal    122
# ..    ...           ...        ...          ...        ...        ...    ...
# 913  45.0            TA        110          264          0     Normal    132
# 914  68.0           ASY        144          193          1     Normal    141
# 915  57.0           ASY        130          131          0     Normal    115
# 916  57.0           ATA        130          236          0        LVH    174
# 917  38.0           NAP        138          175          0     Normal    173
#
#     ExerciseAngina  Oldpeak  HeartDisease  Gender  ST_Slope_Down  \
# 0                N      0.0             0       0              0
# 1                N      1.0             1       1              0
# 2                N      0.0             0       0              0
# 3                Y      1.5             1       1              0
# 4                N      0.0             0       0              0
# ..             ...      ...           ...     ...            ...
# 913              N      1.2             1       0              0
# 914              N      3.4             1       0              0
# 915              Y      1.2             1       0              0
# 916              N      0.0             1       1              0
# 917              N      0.0             0       0              0
#
#      ST_Slope_Flat  ST_Slope_Up
# 0                0            1
# 1                1            0
# 2                0            1
# 3                1            0
# 4                0            1
# ..             ...          ...
# 913              1            0
# 914              1            0
# 915              1            0
# 916              1            0
# 917              0            1
#
# [918 rows x 14 columns]

# %%
chestpain = LabelEncoder()
hrt['ChestPainType'] = chestpain.fit_transform(hrt['ChestPainType'])

# %%
hrt.RestingECG.unique()
# Out:
# array(['Normal', 'ST', 'LVH'], dtype=object)

# %%
ecg = LabelEncoder()
hrt['RestingECG'] = ecg.fit_transform(hrt['RestingECG'])
hrt
# Out:
#       Age  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0    40.0              1        140          289          0           1
# 1    49.0              2        160          180          0           1
# 2    37.0              1        130          283          0           2
# 3    48.0              0        138          214          0           1
# 4    54.0              2        150          195          0           1
# ..    ...            ...        ...          ...        ...         ...
# 913  45.0              3        110          264          0           1
# 914  68.0              0        144          193          1           1
# 915  57.0              0        130          131          0           1
# 916  57.0              1        130          236          0           0
# 917  38.0              2        138          175          0           1
#
#      MaxHR ExerciseAngina  Oldpeak  HeartDisease  Gender  ST_Slope_Down  \
# 0      172              N      0.0             0       0              0
# 1      156              N      1.0             1       1              0
# 2       98              N      0.0             0       0              0
# 3      108              Y      1.5             1       1              0
# 4      122              N      0.0             0       0              0
# ..     ...            ...      ...           ...     ...            ...
# 913    132              N      1.2             1       0              0
# 914    141              N      3.4             1       0              0
# 915    115              Y      1.2             1       0              0
# 916    174              N      0.0             1       1              0
# 917    173              N      0.0             0       0              0
#
#      ST_Slope_Flat  ST_Slope_Up
# 0                0            1
# 1                1            0
# 2                0            1
# 3                1            0
# 4                0            1
# ..             ...          ...
# 913              1            0
# 914              1            0
# 915              1            0
# 916              1            0
# 917              0            1
#
# [918 rows x 14 columns]

# %%
hrt.ExerciseAngina.unique()
# Out:
# array(['N', 'Y'], dtype=object)

# %%
exercise = LabelEncoder()
hrt['ExerciseAngina'] = exercise.fit_transform(hrt['ExerciseAngina'])
hrt
# Out:
#       Age  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0    40.0              1        140          289          0           1
# 1    49.0              2        160          180          0           1
# 2    37.0              1        130          283          0           2
# 3    48.0              0        138          214          0           1
# 4    54.0              2        150          195          0           1
# ..    ...            ...        ...          ...        ...         ...
# 913  45.0              3        110          264          0           1
# 914  68.0              0        144          193          1           1
# 915  57.0              0        130          131          0           1
# 916  57.0              1        130          236          0           0
# 917  38.0              2        138          175          0           1
#
#      MaxHR  ExerciseAngina  Oldpeak  HeartDisease  Gender  ST_Slope_Down  \
# 0      172               0      0.0             0       0              0
# 1      156               0      1.0             1       1              0
# 2       98               0      0.0             0       0              0
# 3      108               1      1.5             1       1              0
# 4      122               0      0.0             0       0              0
# ..     ...             ...      ...           ...     ...            ...
# 913    132               0      1.2             1       0              0
# 914    141               0      3.4             1       0              0
# 915    115               1      1.2             1       0              0
# 916    174               0      0.0             1       1              0
# 917    173               0      0.0             0       0              0
#
#      ST_Slope_Flat  ST_Slope_Up
# 0                0            1
# 1                1            0
# 2                0            1
# 3                1            0
# 4                0            1
# ..             ...          ...
# 913              1            0
# 914              1            0
# 915              1            0
# 916              1            0
# 917              0            1
#
# [918 rows x 14 columns]

# %%
#Take Titanic data and perform encoding
df = pd.read_csv('titanic.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Age'].fillna(np.mean(df['Age']), inplace = True)
# Out:
# C:\Users\kakan\AppData\Local\Temp\ipykernel_20364\1764456069.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(np.mean(df['Age']), inplace = True)

# %%
df['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
df['Embarked'].fillna('S',inplace = True)
df.isna().sum()
# Out:
# C:\Users\kakan\AppData\Local\Temp\ipykernel_20364\2440070343.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Embarked'].fillna('S',inplace = True)
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
df.drop("Cabin", axis=1, inplace=True)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# 886                              Montvila, Rev. Juozas    male  27.000000
# 887                       Graham, Miss. Margaret Edith  female  19.000000
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  29.699118
# 889                              Behr, Mr. Karl Howell    male  26.000000
# 890                                Dooley, Mr. Patrick    male  32.000000
#
#      SibSp  Parch            Ticket     Fare Embarked
# 0        1      0         A/5 21171   7.2500        S
# 1        1      0          PC 17599  71.2833        C
# 2        0      0  STON/O2. 3101282   7.9250        S
# 3        1      0            113803  53.1000        S
# 4        0      0            373450   8.0500        S
# ..     ...    ...               ...      ...      ...
# 886      0      0            211536  13.0000        S
# 887      0      0            112053  30.0000        S
# 888      1      2        W./C. 6607  23.4500        S
# 889      0      0            111369  30.0000        C
# 890      0      0            370376   7.7500        Q
#
# [891 rows x 11 columns]

# %%
df.drop(['PassengerId','Name','Ticket'], inplace=True, axis=True)

# %%
df = pd.get_dummies(df, columns=['Sex'], dtype=int)
df
# Out:
#      Survived  Pclass        Age  SibSp  Parch     Fare Embarked  Sex_female  \
# 0           0       3  22.000000      1      0   7.2500        S           0
# 1           1       1  38.000000      1      0  71.2833        C           1
# 2           1       3  26.000000      0      0   7.9250        S           1
# 3           1       1  35.000000      1      0  53.1000        S           1
# 4           0       3  35.000000      0      0   8.0500        S           0
# ..        ...     ...        ...    ...    ...      ...      ...         ...
# 886         0       2  27.000000      0      0  13.0000        S           0
# 887         1       1  19.000000      0      0  30.0000        S           1
# 888         0       3  29.699118      1      2  23.4500        S           1
# 889         1       1  26.000000      0      0  30.0000        C           0
# 890         0       3  32.000000      0      0   7.7500        Q           0
#
#      Sex_male
# 0           1
# 1           0
# 2           0
# 3           0
# 4           1
# ..        ...
# 886         1
# 887         0
# 888         0
# 889         1
# 890         1
#
# [891 rows x 9 columns]

# %%
df.drop('Sex_male', inplace=True, axis=1)
df = df.rename(columns={'Sex_female':'Gender'})
df
# Out:
#      Survived  Pclass        Age  SibSp  Parch     Fare Embarked  Gender
# 0           0       3  22.000000      1      0   7.2500        S       0
# 1           1       1  38.000000      1      0  71.2833        C       1
# 2           1       3  26.000000      0      0   7.9250        S       1
# 3           1       1  35.000000      1      0  53.1000        S       1
# 4           0       3  35.000000      0      0   8.0500        S       0
# ..        ...     ...        ...    ...    ...      ...      ...     ...
# 886         0       2  27.000000      0      0  13.0000        S       0
# 887         1       1  19.000000      0      0  30.0000        S       1
# 888         0       3  29.699118      1      2  23.4500        S       1
# 889         1       1  26.000000      0      0  30.0000        C       0
# 890         0       3  32.000000      0      0   7.7500        Q       0
#
# [891 rows x 8 columns]

# %%
emb = LabelEncoder()
df['Embarked'] = emb.fit_transform(df['Embarked'])
df
# Out:
#      Survived  Pclass        Age  SibSp  Parch     Fare  Embarked  Gender
# 0           0       3  22.000000      1      0   7.2500         2       0
# 1           1       1  38.000000      1      0  71.2833         0       1
# 2           1       3  26.000000      0      0   7.9250         2       1
# 3           1       1  35.000000      1      0  53.1000         2       1
# 4           0       3  35.000000      0      0   8.0500         2       0
# ..        ...     ...        ...    ...    ...      ...       ...     ...
# 886         0       2  27.000000      0      0  13.0000         2       0
# 887         1       1  19.000000      0      0  30.0000         2       1
# 888         0       3  29.699118      1      2  23.4500         2       1
# 889         1       1  26.000000      0      0  30.0000         0       0
# 890         0       3  32.000000      0      0   7.7500         1       0
#
# [891 rows x 8 columns]

# %% [markdown]
# ### Split data into input features (X) and output feature (y)

# %%
X = df[['Pclass','Age','SibSp','Parch','Fare','Embarked','Gender']]
y = df['Survived']

# %%
print(X.shape)
print(y.shape)
# Out:
# (891, 7)
# (891,)

# %%
x = df.drop('Survived', axis=1)   #Another way to select input columns
x
y = df['Survived']

# %% [markdown]
# ## Splitting the data into train and test
# - Train data should be around 75 to 80% of total values
# - test data should have remaining 25 to 20% of total values

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(X,y,test_size=0.25)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (668, 7)
# (668,)
# (223, 7)
# (223,)

# %%
x_train
# Out:
#      Pclass        Age  SibSp  Parch     Fare  Embarked  Gender
# 877       3  19.000000      0      0   7.8958         2       0
# 460       1  48.000000      0      0  26.5500         2       0
# 717       2  27.000000      0      0  10.5000         2       1
# 411       3  29.699118      0      0   6.8583         1       0
# 25        3  38.000000      1      5  31.3875         2       1
# ..      ...        ...    ...    ...      ...       ...     ...
# 116       3  70.500000      0      0   7.7500         1       0
# 141       3  22.000000      0      0   7.7500         2       1
# 686       3  14.000000      4      1  39.6875         2       0
# 829       1  62.000000      0      0  80.0000         2       1
# 283       3  19.000000      0      0   8.0500         2       0
#
# [668 rows x 7 columns]

# %%
y_train
# Out:
# 877    0
# 460    1
# 717    1
# 411    0
# 25     1
#       ..
# 116    0
# 141    1
# 686    0
# 829    1
# 283    1
# Name: Survived, Length: 668, dtype: int64
