# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_load = pd.read_csv('mtcars.csv')

# %%
data_load.columns
# Out:
# Index(['model', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am',
#        'gear', 'carb'],
#       dtype='object')

# %%
data_load.index
# Out:
# RangeIndex(start=0, stop=32, step=1)

# %%
data_load.shape
# Out:
# (32, 12)

# %%
data_load.dtypes
# Out:
# model     object
# mpg      float64
# cyl        int64
# disp     float64
# hp         int64
# drat     float64
# wt       float64
# qsec     float64
# vs         int64
# am         int64
# gear     float64
# carb       int64
# dtype: object

# %%
data_load
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15    NaN  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
data_load.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  29.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.207310
# std     6.026948   1.785922  123.938694   68.562868   0.534679   1.020562
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.465000
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.215000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.570000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  30.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.700000   2.8125
# std     1.786943   0.504016   0.498991   0.749713   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# ...

# %%
data_load.dtypes
# Out:
# model     object
# mpg      float64
# cyl        int64
# disp     float64
# hp         int64
# drat     float64
# wt       float64
# qsec     float64
# vs         int64
# am         int64
# gear     float64
# carb       int64
# dtype: object

# %%
## check null values

# %%
data_load.isna().sum()
# Out:
# model    0
# mpg      0
# cyl      0
# disp     0
# hp       0
# drat     0
# wt       3
# qsec     0
# vs       0
# am       0
# gear     2
# carb     0
# dtype: int64

# %%
data_load['wt'].fillna(3.0,inplace=True)
# Out:
# C:\Users\kakan\AppData\Local\Temp\ipykernel_17960\660380279.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_load['wt'].fillna(3.0,inplace=True)

# %%
data_load.isna().sum()
# Out:
# model    0
# mpg      0
# cyl      0
# disp     0
# hp       0
# drat     0
# wt       0
# qsec     0
# vs       0
# am       0
# gear     2
# carb     0
# dtype: int64

# %%
## gear     

x= data_load['gear'].mode()

data_load['gear'].fillna(3.0, inplace=True)
# Out:
# C:\Users\kakan\AppData\Local\Temp\ipykernel_17960\2718402313.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_load['gear'].fillna(3.0, inplace=True)

# %%
data_load.isna().sum()
# Out:
# model    0
# mpg      0
# cyl      0
# disp     0
# hp       0
# drat     0
# wt       0
# qsec     0
# vs       0
# am       0
# gear     0
# carb     0
# dtype: int64

# %%
##  set index  and resetindex

# %%
data_load.index
# Out:
# RangeIndex(start=0, stop=32, step=1)

# %%
data_load.set_index('model', inplace=True    )

# %%
data_load
# Out:
#                       mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# model
# Mazda RX4            21.0    6  160.0  110  3.90  2.620  16.46   0   1   4.0
# Mazda RX4 Wag        21.0    6  160.0  110  3.90  2.875  17.02   0   1   4.0
# Datsun 710           22.8    4  108.0   93  3.85  2.320  18.61   1   1   3.0
# Hornet 4 Drive       21.4    6  258.0  110  3.08  3.215  19.44   1   0   3.0
# Hornet Sportabout    18.7    8  360.0  175  3.15  3.000  17.02   0   0   3.0
# Valiant              18.1    6  225.0  105  2.76  3.460  20.22   1   0   3.0
# Duster 360           14.3    8  360.0  245  3.21  3.570  15.84   0   0   3.0
# Merc 240D            24.4    4  146.7   62  3.69  3.190  20.00   1   0   4.0
# Merc 230             22.8    4  140.8   95  3.92  3.150  22.90   1   0   4.0
# Merc 280             19.2    6  167.6  123  3.92  3.440  18.30   1   0   4.0
# Merc 280C            17.8    6  167.6  123  3.92  3.440  18.90   1   0   4.0
# ...

# %%
data_load.reset_index(inplace=True)

# %%
data_load
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.000  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %% [markdown]
# ![image.png](attachment:3c10507f-2f80-4288-894e-cf02bd0eaef3.png)

# %%
data_load

data_load.plot(kind='hist', alpha = 0.5, edgecolor = 'black')
# Out:
# <Axes: ylabel='Frequency'>

# %%
col =data_load.columns

# %%
## import matplotlib.pyplot as plt

plt.figure(figsize=(15,4))
plt.plot(data_load['model'],data_load['hp'], marker = 'o', color = 'red')

plt.xticks(rotation = 85)
plt.xlabel('Name of the car ')
plt.ylabel('hp ')
plt.title('HP vs CARS')
plt.show()

# %%
print(col)
# Out:
# Index(['model', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am',
#        'gear', 'carb'],
#       dtype='object')

# %%
plt.figure(figsize=(10, 5))
data_load['hp'].plot(kind='hist', bins=20, alpha=0.7, color='blue', edgecolor='black')
plt.title('Histogram of Horsepower')
plt.xlabel('Horsepower')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10, 5))
#data_load['hp'].plot(kind='hist', bins=20, alpha=0.7, color='blue', edgecolor='black')

plt.hist(data_load['hp'], bins=20, alpha=0.7, color='blue', edgecolor='black')
plt.title('Histogram of Horsepower')
plt.xlabel('Horsepower')
plt.ylabel('Frequency')
plt.show()

# %%
##scatter 

print(col)
# Out:
# Index(['model', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am',
#        'gear', 'carb'],
#       dtype='object')

# %%
plt.figure(figsize=(10, 5))

plt.scatter(data_load['hp'],data_load['mpg'], color = 'blue', alpha=0.5 )

plt.grid()
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.boxplot(data_load['hp'])
plt.grid()
plt.show()

# %%
gares_piv = data_load['gear'].value_counts()
gares_piv
# Out:
# gear
# 3.0    16
# 4.0    11
# 5.0     5
# Name: count, dtype: int64

# %%
print(gares_piv)
# Out:
# gear
# 3.0    16
# 4.0    11
# 5.0     5
# Name: count, dtype: int64

# %%
# Out:
# Index([3.0, 4.0, 5.0], dtype='float64', name='gear')

# %%
plt.figure(figsize=(10, 5))

plt.pie(gares_piv.values , labels= gares_piv.index,autopct='%1.1f%%' )

plt.show()
